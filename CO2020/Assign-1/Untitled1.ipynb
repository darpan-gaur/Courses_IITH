# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = 'inp.csv'
df = pd.read_csv(file)
# df1 = pd.read_csv('inp1.csv')
df
# Out:
#         t         x
# 0     0.0  0.500000
# 1     0.1  0.507804
# 2     0.2  0.510944
# 3     0.3  0.509026
# 4     0.4  0.501681
# ..    ...       ...
# 296  29.6 -1.842863
# 297  29.7 -1.786493
# 298  29.8 -1.725148
# 299  29.9 -1.659121
# 300  30.0 -1.588463
#
# [301 rows x 2 columns]

# %%
x = df['t'].to_numpy()
# y = df['T'].to_numpy()
y1 = df['x'].to_numpy()
# y3 = df['Exact Solution'].to_numpy()
# y2 = df1['Approximate Solution'].to_numpy()
# er = df['Absolute Error'].to_numpy()

# %%
plt.figure(0)
plt.plot(x,y1)
# plt.figure(1)
plt.plot(x,y2,label = 'ABM-4')
# plt.plot(x,y3,label = 'Exact')
# plt.hlines(y[len(y)-1], 0,x[len(x)-1])
plt.xlabel("$t$", fontsize=16)
plt.ylabel("$x$", fontsize=16)
# plt.legend()
# Out:
# Text(0, 0.5, '$x$')

# %%
plt.figure()
plt.plot(x,er)
